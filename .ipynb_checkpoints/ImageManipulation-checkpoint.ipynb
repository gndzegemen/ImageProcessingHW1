# %% [markdown]
# # Installation

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\egemen\anaconda3\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\egemen\anaconda3\lib\site-packages (from opencv-python) (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\egemen\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\egemen\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\egemen\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\egemen\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\egemen\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\egemen\anaconda3\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\egemen\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\egemen\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\egemen\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\egemen\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\egemen\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import

# %%
import math
import numpy as np
import cv2

# %% [markdown]
# ## Functions

# %%
def well(x: float) -> float:
    result = 1 - 2 / ((1 + x * x) ** 8)
    return 1 if result < -1 else result

# %%
def float_color_to_int(c: float) -> int:
    return max(0, min(255, int(128 * (c + 1))))

# %%
def int_rgb(r: float, g: float, b: float):
    return (
        float_color_to_int(r),
        float_color_to_int(g),
        float_color_to_int(b),
        255,
    )

# %%
def polar(x: int, y: int, size: int, polar_shift):
    x = x - polar_shift[0] * size
    y = y - polar_shift[1] * size
    u = math.sqrt(x * x + y * y) / size
    v = 0 if x == 0 else math.atan(y / x) * 2 / math.pi
    return u, v

# %%
def dist(c1, c2):
    return math.sqrt(
        (c1[0] - c2[0]) ** 2 +
        (c1[1] - c2[1]) ** 2 +
        (c1[2] - c2[2]) ** 2
    )

# %% [markdown]
# ## Image Generation

# %%
def render_mathartist_equivalent(size=512, polar_shift=(0.5, 0.5)):
    img = np.zeros((size, size, 4), dtype=np.uint8)

    rand1 = (0.574928, 0.255763, 0.100623)
    rand2 = (0.03488, 0.156455, 0.524925)
    phase = 2.85516
    freq = 5.24514

    c2 = (
        math.sin(phase + freq * rand2[0]),
        math.sin(phase + freq * rand2[1]),
        math.sin(phase + freq * rand2[2]),
    )

    for py in range(size):
        for px in range(size):
            u, v = polar(px, py, size, polar_shift)

            target_value = well(u)
            target = (target_value, target_value, target_value)

            c1 = (
                rand1[0] * v,
                rand1[1] * v,
                rand1[2] * v,
            )

            color = c1 if dist(c1, target) > dist(c2, target) else c2
            img[py, px] = int_rgb(*color)

    return img

# %%
from matplotlib import pyplot as plt

# %%
img_rgba = render_mathartist_equivalent(512, (0.5, 0.5))

# %%
plt.imshow(img_rgba)
plt.axis("off")
plt.show()

# %% [markdown]
# Görsel, her piksel için uygulanan şu parçalı renk fonksiyonu ile üretilmektedir:
#
# $$
# u = \frac{\sqrt{(p_x-0.5N)^2 + (p_y-0.5N)^2}}{N}
# $$
#
# $$
# v =
# \begin{cases}
# 0, & p_x-0.5N = 0 \\
# \frac{2}{\pi}\arctan\left(\frac{p_y-0.5N}{p_x-0.5N}\right), & \text{aksi halde}
# \end{cases}
# $$
#
# $$
# \operatorname{well}(u)=1-\frac{2}{(1+u^2)^8}
# $$
#
# $$
# T(u)=\left(\operatorname{well}(u),\operatorname{well}(u),\operatorname{well}(u)\right)
# $$
#
# $$
# C_1(v)=\left(0.574928v,\;0.255763v,\;0.100623v\right)
# $$
#
# $$
# C_2=\left(
# \sin(2.85516+5.24514\cdot0.03488),\;
# \sin(2.85516+5.24514\cdot0.156455),\;
# \sin(2.85516+5.24514\cdot0.524925)
# \right)
# $$
#
# $$
# C(u,v)=
# \begin{cases}
# C_1(v), & \|C_1(v)-T(u)\| > \|C_2-T(u)\| \\
# C_2, & \text{aksi halde}
# \end{cases}
# $$
